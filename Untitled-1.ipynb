# %% [markdown]
# Welcome to AI course

# %% [markdown]
# here we gonna write our first code ;)

# %%
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# You can even write mutiple code in a program

# %%
print("Hello, World!")
print("My name is Pouya Kelich")
# Out:
# Hello, World!
# My name is Pouya Kelich

# %% [markdown]
# Now we gonna learn about diffrent types of variable in python

# %%
print("12")
# Out:
# 12

# %%
print(12)
# Out:
# 12

# %%
print(12.56)
# Out:
# 12.56

# %% [markdown]
# We have 4 diffrent types of data in python
# 1-integer
# 2-float
# 3-string
# 4-boolean

# %%
type(12.56)
# Out:
# float

# %%
type("aspdjaspd")
# Out:
# str

# %%
type(12)
# Out:
# int

# %%
type("12")
# Out:
# str

# %%
print(type(12.56))
print(type("aspdjaspd"))
print(type(12))
print(type("123"))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'int'>
# <class 'str'>

# %% [markdown]
# now we gonna learn about operators
# sum = +
# Subtraction = -
# Multiplication = *
# raise to the power = **
# Division = /
# Integer division = //
# Modulo = %

# %%
10+5
# Out:
# 15

# %%
10-5
# Out:
# 5

# %%
10/5
# Out:
# 2.0

# %%
10//5
# Out:
# 2

# %%
type(10 // 5)
# Out:
# int

# %%
11/5
# Out:
# 2.2

# %%
type(10 / 5)
# Out:
# float

# %%
11//5
# Out:
# 2

# %%
type(10 // 5)
# Out:
# int

# %%
10%5
# Out:
# 0

# %%
11%5
# Out:
# 1

# %%
2 ** 3
# Out:
# 8

# %%
3**2
# Out:
# 9

# %% [markdown]
# Now we wanna see what is variable and how we can make one ;)

# %%
name = "Pouya"
age = 24
score = 18.75

# %% [markdown]
# Whenever we want we can change the value of our variable

# %%
score = 19.5

# %% [markdown]
# Now we can print our variable

# %%
print(name)
print(age)
print(score)
# Out:
# Pouya
# 24
# 19.5

# %% [markdown]
# Lets see what is the type of our variables

# %%
print(type(name))
print(type(age))
print(type(score))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# Tip: we cant add string to integer!!!!!

# %%
"12" + 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[256], line 1
# ----> 1 "12" + 3
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# as you can see the python compiler send us an error so be carefull ;)

# %% [markdown]
# We can get average for our scores and then print it

# %%
nomre1 = 15
nomre2 = 12
nomre3 = 18

miangin = (nomre1 + nomre2 + nomre3) / 3
print(miangin)

# %% [markdown]
# Now we wanna learn about TypeCastin
# typecasting means that change the type of variables like changing a string to integer

# %%
adad1 = "12"
type(adad1)
# Out:
# str

# %%
adad1 = "12"
type(int(adad1))
# Out:
# int

# %%
adad1 = "12.23"
adad2= 13

float(adad1) + adad2
# Out:
# 25.23

# %%
str(12)

# %% [markdown]
# Tip : we cant add a string type to integer type but we can add two string types with each other

# %%
'Pouya' + ' Kelich'
# Out:
# 'Pouya Kelich'

# %% [markdown]
# we can use this methods for print too

# %%
name = "Pouya"
lastname = "Kelich"
age = 24
score = 18.75

print("Man "+ name+lastname+" hastam. "+str(age)+" salame."+" nomre man "+str(score)+" ast." )
# Out:
# Man PouyaKelich hastam. 24 salame. nomre man 18.75 ast.

# %%
name = "Pouya"
lastname = "Kelich"
age = 24
score = 18.75

print("Man "+ name+" "+lastname+" hastam. "+str(age)+" salame."+" nomre man "+str(score)+" ast." )
# Out:
# Man Pouya Kelich hastam. 24 salame. nomre man 18.75 ast.

# %% [markdown]
# You dont have to write all the variables in single box again you can instantly print

# %%
print("Man "+ name+" "+lastname+" hastam. "+str(age)+" salame."+" nomre man "+str(int(score))+" ast." )
# Out:
# Man Pouya Kelich hastam. 24 salame. nomre man 18 ast.

# %% [markdown]
# Now we gonna one new method that is very usefull in programming and its called Input

# %%
name = input()

# %%
print(name)

# %%
name = input("enter your name please:")

# %%
print("My name is: " + name)
# Out:
# My name is: Pouya

# %% [markdown]
# You can also write with diffrent languages in the input box

# %%
name = input("اسم خود را واریسد")

# %%
print("My name is: " + name)
# Out:
# My name is: پویا

# %% [markdown]
# Tip:Be carefull when you use input your variable type will be string

# %%
age = input("please enter your age:")

# %%
type(age)
# Out:
# str

# %% [markdown]
# If you want to change the input type you can use the typecasting method before the input

# %%
age = int(input("please enter your age:"))

# %%
type(age)
# Out:
# int

# %% [markdown]
# Now you can use operators for your variable

# %%
1405 - age
# Out:
# 1381

# %% [markdown]
# You can also use float() for making your string type to float type this is usefull when you want to get a float number like score

# %%
score = float(input("please enter your score:"))
score + 1
# Out:
# 20.0

# %% [markdown]
# you can use print method like this

# %%
firstname = input("please enter your name:")
lastname = input("please enter your lastname:")

print(firstname, lastname)
# Out:
# pouya kelich

# %%
name = input()
a = float(input())
b = float(input())
c = float(input())

y = (a*b)**c

print("man "+name+" hastam. Natije mohasabetam "+str(y)+ " shod.")

# %% [markdown]
# We can add comment to our code that doesnt affect our code just its for ourself for adding note

# %%
#this code prints Hello
print("Hello!")
# Out:
# Hello!

# %% [markdown]
# Assignment:
